# %%
#Import required libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the data and set column name as well

df= pd.read_csv('pima_indian_diabetes.csv', header=None, names=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome'])

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Dataset size

df.shape    # 768 Rows and 9 Columns
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# Check Null values

df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# Visualization os Null values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Lets EDA

# %%
#Lets observe eacl feature with target variable

sns.scatterplot(x='Pregnancies', y= 'Outcome', data=df )
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Outcome'>

# %% [markdown]
#  Conclusion
# Pregnent women of 0 to 13 months have equal chances of having diabetes (50-50%) because data is equally distributed
#  Women pregnent more than 4 month have higher changes of having diabetes

# %%
# Glucose vs outcome

sns.scatterplot(x='Glucose', y= 'Outcome', data=df )
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Outcome'>

# %% [markdown]
#  Glucose data is equally distributed between 55 to 200, if Glucose level is very low have low chances of diabetes

# %%
#BloodPressure vs outcome

sns.scatterplot(x='BloodPressure', y= 'Outcome', data=df )
# Out:
# <AxesSubplot:xlabel='BloodPressure', ylabel='Outcome'>

# %% [markdown]
#  Blood Pressure is equally distributed between 45 to 100

# %%
#SkinThichness vs outcome

sns.scatterplot(x='SkinThickness', y= 'Outcome', data=df )
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Outcome'>

# %% [markdown]
# SkinThichness is equally distributed in range 5 to 55, Thichness more than 55 have high chances of diabetes

# %%
#Insulin vs outcome

sns.scatterplot(x='Insulin', y= 'Outcome', data=df )
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Outcome'>

# %% [markdown]
# #Insulin have equally distributed data till 375,

# %%
#BMI vs outcome

sns.scatterplot(x='BMI', y= 'Outcome', data=df )
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Outcome'>

# %% [markdown]
# BMI equally distributed between 25 to 50, BMI more than 50 have high chances of diabetes

# %%
#'DiabetesPedigreeFunction' vs outcome

sns.scatterplot(x='DiabetesPedigreeFunction', y= 'Outcome', data=df )
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction', ylabel='Outcome'>

# %%
#'Age' vs outcome

sns.scatterplot(x='Age', y= 'Outcome', data=df )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Outcome'>

# %% [markdown]
# After Age 60, less change of having diabete

# %%
sns.pairplot(df)

# %%
sns.histplot(df['Pregnancies'],kde=True)
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Count'>

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#Lets observe correlation of all columns vs output

df.corr()['Outcome'].sort_values()
# Out:
# BloodPressure               0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# DiabetesPedigreeFunction    0.173844
# Pregnancies                 0.221898
# Age                         0.238356
# BMI                         0.292695
# Glucose                     0.466581
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(), annot=True,linewidths=.5, linecolor='black', fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [raw]
# #Conclusion:
# BloodPressure, SkinThichness, Insulin  has a weak bond with target column
# Pregnancies, BMI and Age has good correlation
# Glucose has strong correlation with target

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
plt.figure(figsize=(12,9))
sns.heatmap(round(df.describe()[1:].transpose(),2), annot=True,linewidths=2,fmt='.2f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=10)
plt.title("variable Summary")
plt.savefig('heatmap.png')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# # Checking outliers

# %%
# With Boxplot

columnlist= df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*nrows))
for i in range(0, len(columnlist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data=df[columnlist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# # Skewness()

# %%
df.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %% [raw]
# lets take skewness +/- 6.5 here

# %% [markdown]
# # Normal Distribution Curve

# %%
sns.distplot(df['Pregnancies'])
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Density'>

# %%
sns.distplot(df['Glucose'])
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Density'>

# %%
sns.distplot(df['BloodPressure'])
# Out:
# <AxesSubplot:xlabel='BloodPressure', ylabel='Density'>

# %%
sns.distplot(df['SkinThickness'])
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Density'>

# %%
sns.distplot(df['Insulin'])
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Density'>

# %%
sns.distplot(df['BMI'])
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Density'>

# %%
sns.distplot(df['DiabetesPedigreeFunction'])
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction', ylabel='Density'>

# %% [markdown]
# The Normal distribution shows that the data is skewed

# %% [markdown]
# # Data Cleaning

# %%
df.corr()['Outcome']
# Out:
# Pregnancies                 0.221898
# Glucose                     0.466581
# BloodPressure               0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# BMI                         0.292695
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %% [raw]
# we are setting threshold of correlation as +/- 0.1, so drop least correlated columns

# %%
df= df.drop(['BloodPressure','SkinThickness'], axis=1)

# %%
df
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 0              6      148        0  33.6                     0.627   50
# 1              1       85        0  26.6                     0.351   31
# 2              8      183        0  23.3                     0.672   32
# 3              1       89       94  28.1                     0.167   21
# 4              0      137      168  43.1                     2.288   33
# ..           ...      ...      ...   ...                       ...  ...
# 763           10      101      180  32.9                     0.171   63
# 764            2      122        0  36.8                     0.340   27
# 765            5      121      112  26.2                     0.245   30
# 766            1      126        0  30.1                     0.349   47
# 767            1       93        0  30.4                     0.315   23
#
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# ...

# %% [markdown]
# # Removing outliers

# %%
# Zscore

#IQR Proximity rule

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
Threshold=3

# %%
# index numbers
print(np.where(z>3))
# Out:
# (array([  4,   8,   9,  13,  45,  49,  58,  60,  75,  81,  88, 111, 123,
#        145, 153, 159, 177, 182, 186, 220, 228, 228, 247, 286, 298, 330,
#        342, 349, 370, 370, 371, 371, 395, 409, 415, 426, 445, 445, 453,
#        455, 459, 486, 494, 502, 522, 584, 593, 621, 645, 655, 666, 673,
#        684, 684, 695, 706, 753], dtype=int64), array([4, 2, 3, 2, 4, 3, 4, 3, 1, 3, 0, 2, 5, 3, 2, 0, 3, 1, 2, 2, 2, 4,
#        2, 2, 0, 4, 1, 1, 2, 4, 3, 4, 4, 2, 2, 3, 3, 4, 5, 0, 5, 2, 3, 1,
#        3, 2, 4, 4, 2, 2, 5, 3, 3, 5, 2, 3, 2], dtype=int64))

# %%
df_new= df[(z<3).all(axis=1)]

# %%
print("old dataframe ",df.shape)
# Out:
# (768, 7)

# %%
print("new dataframe",df_new.shape)
# Out:
# (716, 7)

# %%
print("deleted rows ", df.shape[0]- df_new.shape[0])
# Out:
# deleted rows  52

# %% [markdown]
# # Percentage of data loss:

# %%
loss_percentage= (768-716)/768*100

# %%
loss_percentage
# Out:
# 6.770833333333333

# %% [markdown]
# # Train split

# %%
df_new
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 0              6      148        0  33.6                     0.627   50
# 1              1       85        0  26.6                     0.351   31
# 2              8      183        0  23.3                     0.672   32
# 3              1       89       94  28.1                     0.167   21
# 5              5      116        0  25.6                     0.201   30
# ..           ...      ...      ...   ...                       ...  ...
# 763           10      101      180  32.9                     0.171   63
# 764            2      122        0  36.8                     0.340   27
# 765            5      121      112  26.2                     0.245   30
# 766            1      126        0  30.1                     0.349   47
# 767            1       93        0  30.4                     0.315   23
#
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 5          0
# ..       ...
# ...

# %%
#independent column

x=df_new.iloc[:,:-1]

# %%
# target
y=df_new.iloc[:,-1]

# %% [markdown]
# # Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')  # boxcox is for +ve vales only because it use log function

# %%
x
# Out:
# array([[ 0.81372962,  0.95226949, -1.00352346,  0.27687564,  0.87489585,
#          1.35198907],
#        [-0.85335591, -1.28911332, -1.00352346, -0.83154158, -0.12001485,
#          0.17882712],
#        [ 1.21128383,  1.80917056, -1.00352346, -1.42780246,  0.98599923,
#          0.28187245],
#        ...,
#        [ 0.58087093,  0.14030575,  0.96418892, -0.90087148, -0.7403492 ,
#          0.0672049 ],
#        [-0.85335591,  0.30366985, -1.00352346, -0.25458483, -0.13008754,
#          1.23684281],
#        [-0.85335591, -0.92513082, -1.00352346, -0.20739102, -0.3102124 ,
#         -1.06600933]])

# %%
# scaling  0-1
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.81372962,  0.95226949, -1.00352346,  0.27687564,  0.87489585,
#          1.35198907],
#        [-0.85335591, -1.28911332, -1.00352346, -0.83154158, -0.12001485,
#          0.17882712],
#        [ 1.21128383,  1.80917056, -1.00352346, -1.42780246,  0.98599923,
#          0.28187245],
#        ...,
#        [ 0.58087093,  0.14030575,  0.96418892, -0.90087148, -0.7403492 ,
#          0.0672049 ],
#        [-0.85335591,  0.30366985, -1.00352346, -0.25458483, -0.13008754,
#          1.23684281],
#        [-0.85335591, -0.92513082, -1.00352346, -0.20739102, -0.3102124 ,
#         -1.06600933]])

# %% [markdown]
# # Since outcome has only 2 variables, we will use binary classification model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression()
from sklearn.metrics import accuracy_score

# %%
#  Find best random_state

for i in range(0,1000):
    x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=i, test_size=.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test= lr.predict(x_test)
    if round(accuracy_score(y_train, pred_train)*100,1   )==round(accuracy_score(y_test,pred_test)*100,1):
        print("At random state ", i, "The model performance very well")
        print("At random state: ",i)
        print("Training accuracy score is: ", round(accuracy_score(y_train,pred_train)*100,2))
        print('Testing acuracy_score is ', round(accuracy_score(y_test,pred_test)*100,2))
        print('X'*50,'\n')
# Out:
# At random state  0 The model performance very well
# At random state:  0
# Training accuracy score is:  77.8
# Testing acuracy_score is  77.78
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  57 The model performance very well
# At random state:  57
# Training accuracy score is:  77.8
# Testing acuracy_score is  77.78
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  247 The model performance very well
# At random state:  247
# Training accuracy score is:  77.8
# Testing acuracy_score is  77.78
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  321 The model performance very well
# At random state:  321
# Training accuracy score is:  77.8
# Testing acuracy_score is  77.78
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  383 The model performance very well
# At random state:  383
# Training accuracy score is:  78.5
# Testing acuracy_score is  78.47
# ...

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.2,random_state=771)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.71      0.69        96
#            1       0.33      0.29      0.31        48
#
#     accuracy                           0.57       144
#    macro avg       0.50      0.50      0.50       144
# weighted avg       0.56      0.57      0.56       144

# %% [markdown]
# # Cross Validation score for logistic regression

# %%
pred_lr=lr.predict(x_test)

from sklearn.model_selection import cross_val_score
lss= accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore= cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    print("At CV ", j)
    print('cross validation score is ', lsc*100)
    print('accuracy score is ',lss*100)
    print('\n')
# Out:
# At CV  2
# cross validation score is  77.37430167597765
# accuracy score is  79.16666666666666
#
#
# At CV  3
# cross validation score is  77.23767331200263
# accuracy score is  79.16666666666666
#
#
# At CV  4
# cross validation score is  77.23463687150839
# accuracy score is  79.16666666666666
#
#
# At CV  5
# cross validation score is  77.0959595959596
# accuracy score is  79.16666666666666
#
#
# At CV  6
# cross validation score is  77.51750700280112
# accuracy score is  79.16666666666666
#
#
# At CV  7
# cross validation score is  76.82004840771259
# accuracy score is  79.16666666666666
#
#
# At CV  8
# cross validation score is  77.10830212234707
# accuracy score is  79.16666666666666
#
#
# At CV  9
# cross validation score is  77.24683544303797
# accuracy score is  79.16666666666666

# %% [raw]
# Since Crossvalidation score accuracy are almost same, we are heading with a good approach

# %%
lsscore_selected= cross_val_score(lr,x,y,cv=6).mean()
print("The CV score is: ", lsscore_selected,'\n The accuracy score is: ',lss)
# Out:
# The CV score is:  0.7751750700280112
#  The accuracy score is:  0.7916666666666666

# %% [markdown]
# # The model with the outliers

# %% [markdown]
# # AUC ROC curve:
